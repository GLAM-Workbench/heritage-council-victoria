# %% [markdown]
# # Introduction to the Victorian Heritage Database API
#
# The [Victorian Heritage Register](https://heritagecouncil.vic.gov.au/heritage-protection/register/) maintains the [Victorian Heritage Database](https://vhd.heritagecouncil.vic.gov.au/)
# which contains information about the state's most significant places. The databse can be searched through
# the website, but it can also be accessed through an unauthenticated API. This means there is no need to
# register to get started. You just start!
#
# The API is documented at:
#
# > https://api.heritagecouncil.vic.gov.au/documentation
#
# The API is so easy to use that you can make your first API request simply by loading a URL:
#
# > https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities?hasListings=true
#
# Easy!
#
# This URL returns all of the heritage authories that have at least one listing. These include
# Heritage Victoria, various Local Government Authorities, The Victorian War Heritage Inventory
# and the National Trust. Not that you could tell these are the authorities because the webpage
# formatting is almost impossible to read. The format is called [JSON](https://www.w3schools.com/js/js_json_intro.asp)
# and it is easy for computers to read, but humans can struggle. It’s a bit like HTML. So let's
# use some code to load the JSON data and  output it in a slightly more human friendly manner.

# %%
# First, get set up to make some 'requests' for data and work with 'json'.
import json

import requests

# %%
# Next, specify the API URL we wish to load:
myURL = (
    "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities?hasListings=true"
)
# Now load that URL:
myLoadedURL = requests.get(myURL)
# Treat the loaded data as JSON rather than just plain text:
myJSONdata = json.loads(myLoadedURL.text)
# Finally, output the information with nice indents and other formatting:
print(json.dumps(myJSONdata, indent=4, sort_keys=True))
# Out:
# {
#     "_embedded": {
#         "heritage_authority": [
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Ballarat City",
#                 "id": "61"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Banyule City",
#                 "id": "38"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Boroondara City",
#                 "id": "5"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Brimbank City",
#                 "id": "60"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Cardinia Shire",
#                 "id": "28"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Casey City",
#                 "id": "48"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Darebin City",
#                 "id": "13"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Glen Eira City",
#                 "id": "42"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Glenelg Shire",
#                 "id": "33"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Golden Plains Shire",
#                 "id": "14"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Greater Bendigo City",
#                 "id": "39"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Greater Geelong City",
#                 "id": "6"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Hindmarsh",
#                 "id": "102"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Hobsons Bay City",
#                 "id": "7"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Manningham City",
#                 "id": "8"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Maribyrnong City",
#                 "id": "17"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Maroondah City",
#                 "id": "85"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Melton City",
#                 "id": "25"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Moonee Valley City",
#                 "id": "15"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Moorabool Shire",
#                 "id": "79"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Moreland City",
#                 "id": "31"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "National Trust",
#                 "id": "58"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Nillumbik Shire",
#                 "id": "46"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Northern Grampians Shire",
#                 "id": "65"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Queenscliffe Borough",
#                 "id": "49"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "South Gippsland Shire",
#                 "id": "35"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Southern Grampians Shire",
#                 "id": "10"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Stonnington City",
#                 "id": "30"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Vic. War Heritage Inventory",
#                 "id": "83"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "HI",
#                 "heritage_authority_name": "Victorian Heritage Inventory",
#                 "id": "1087"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "VHR",
#                 "heritage_authority_name": "Victorian Heritage Register",
#                 "id": "1086"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Yarra City",
#                 "id": "50"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities"
#                     }
#                 },
#                 "heritage_authority_brief": "",
#                 "heritage_authority_name": "Yarra Ranges Shire",
#                 "id": "75"
#             }
#         ]
#     },
#     "_links": {
#         "self": {
#             "href": "https://api.heritagecouncil.vic.gov.au/v1/heritage-authorities?hasListings=true"
#         }
#     },
#     "total_items": 33
# }

# %% [markdown]
# That's nice. We can now read through the data to get a sense of all of the names of all of the heritage
# authorities that have information in the database. Don't worry if you don't understand everything. But
# you can probably spot some interesting information.
#
# Let's do a search for cats in the database using the API! The API documentation says we can search places using:
#
# > /places?kw=some+words
#
# The *kw* probably stands for key word. It is a keyword search. So let's change the keyword search to **cats**:
#
# > /places?kw=**cats**
#
# And then we need to add in the start of the URL for the API:
#
# > https://api.heritagecouncil.vic.gov.au/v1/places?kw=cats
#
# Making that API request through your web browswer seems to work. But we'll need to use code to make the response more
# human readable.

# %%
myURL = "https://api.heritagecouncil.vic.gov.au/v1/places?kw=cats"
myLoadedURL = requests.get(myURL)
myJSONdata = json.loads(myLoadedURL.text)
print(json.dumps(myJSONdata, indent=4, sort_keys=True))
# Out:
# {
#     "_embedded": {
#         "places": [
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/55888"
#                     }
#                 },
#                 "heritage_authority_brief": "VHR",
#                 "heritage_authority_id": "1086",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/1086.gif",
#                 "heritage_authority_name": "Victorian Heritage Register",
#                 "id": 55888,
#                 "latlon": "-35.450770,143.627040",
#                 "location": "WILLAKOOL DRIVE LAKE BOGA, SWAN HILL RURAL CITY",
#                 "name": "LAKE BOGA FLYING BOAT MUSEUM",
#                 "overlay_numbers": [
#                     "HO43"
#                 ],
#                 "primary_image_caption": "H2208 lake boga plan",
#                 "primary_image_id": 66223,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/066/223.jpg",
#                 "score": 0.5658388,
#                 "summary": "The Lake Boga Flying Boat Museum is located on a foreshore site which was part of the World War II RAAF Flying Boat Repair Depot. It features an original communications bunker, slipways, a&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/55888",
#                 "vhr_number": "H2208"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/4781"
#                     }
#                 },
#                 "heritage_authority_brief": "VHR",
#                 "heritage_authority_id": "1086",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/1086.gif",
#                 "heritage_authority_name": "Victorian Heritage Register",
#                 "id": 4781,
#                 "latlon": "-37.784720,144.952410",
#                 "location": "ELLIOTT AVENUE PARKVILLE, MELBOURNE CITY",
#                 "name": "ROYAL MELBOURNE ZOOLOGICAL GARDENS",
#                 "overlay_numbers": [
#                     "HO364",
#                     "HO822",
#                     "HO823",
#                     "HO824",
#                     "HO830",
#                     "HO831",
#                     "HO826",
#                     "HO825",
#                     "HO828",
#                     "HO829",
#                     "HO827"
#                 ],
#                 "primary_image_caption": "ROYAL MELBOURNE ZOOLOGICAL GARDENS SOHE 2008",
#                 "primary_image_id": 78765,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/078/765.jpg",
#                 "score": 0.55806905,
#                 "summary": "The Royal Melbourne Zoological Gardens including the Formal Garden Layout and elephant statue; former Mandrill House; former Monkey House; Great Flight Aviary; Giraffe House and Enclosure;&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/4781",
#                 "vhr_number": "H1074"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/180"
#                     }
#                 },
#                 "heritage_authority_brief": "VHR",
#                 "heritage_authority_id": "1086",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/1086.gif",
#                 "heritage_authority_name": "Victorian Heritage Register",
#                 "id": 180,
#                 "latlon": "-37.757320,145.083100",
#                 "location": "7 TEMPLESTOWE ROAD BULLEEN, Manningham City",
#                 "name": "HEIDE II",
#                 "overlay_numbers": [
#                     "HO161"
#                 ],
#                 "primary_image_caption": "HEIDE II SOHE 2008",
#                 "primary_image_id": 77600,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/077/600.jpg",
#                 "score": 0.55666137,
#                 "summary": "Designed by David McGlashan of the firm McGlashan &amp; Everist, Heide II was built in 1967 as 'a gallery that could be lived in' for art patrons John and Sunday Reed who had been living on&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/180",
#                 "vhr_number": "H1494"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/1774"
#                     }
#                 },
#                 "heritage_authority_brief": "VHR",
#                 "heritage_authority_id": "1086",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/1086.gif",
#                 "heritage_authority_name": "Victorian Heritage Register",
#                 "id": 1774,
#                 "latlon": "-36.757230,144.279090",
#                 "location": "PALL MALL and VIEW STREET and GAOL ROAD and PARK ROAD BENDIGO, Greater Bendigo City",
#                 "name": "ROSALIND PARK",
#                 "overlay_numbers": [
#                     "HO10"
#                 ],
#                 "primary_image_caption": "ROSALIND PARK SOHE 2008",
#                 "primary_image_id": 78410,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/078/410.jpg",
#                 "score": 0.5552536,
#                 "summary": "The area known as Rosalind Park (formerly Government Camp Precinct) was first mapped by Surveyor George Urquhart, and designated a Government Camp, in 1852 to serve the local goldfields. The&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/1774",
#                 "vhr_number": "H1866"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/11057"
#                     }
#                 },
#                 "heritage_authority_brief": "HI",
#                 "heritage_authority_id": "1087",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/1087.gif",
#                 "heritage_authority_name": "Victorian Heritage Inventory",
#                 "hi_number": "H8423-0012",
#                 "id": 11057,
#                 "latlon": "-37.418580,147.656820",
#                 "location": "MOUNT DOW TRACK STIRLING, EAST GIPPSLAND SHIRE",
#                 "name": "BLACK CAT BATTERY",
#                 "score": 0.44395262,
#                 "url": "http://vhd.heritage.vic.gov.au/places/11057",
#                 "vhr_number": null
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/7906"
#                     }
#                 },
#                 "heritage_authority_brief": "HI",
#                 "heritage_authority_id": "1087",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/1087.gif",
#                 "heritage_authority_name": "Victorian Heritage Inventory",
#                 "hi_number": "H7723-0234",
#                 "id": 7906,
#                 "latlon": "-37.035500,144.262460",
#                 "location": "CAT DAM TRACK BARKERS CREEK, MOUNT ALEXANDER SHIRE",
#                 "name": "CAPPERS REEF WORKINGS",
#                 "score": 0.29794455,
#                 "url": "http://vhd.heritage.vic.gov.au/places/7906",
#                 "vhr_number": null
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/197859"
#                     }
#                 },
#                 "heritage_authority_id": "75",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/75.gif",
#                 "heritage_authority_name": "Yarra Ranges Shire",
#                 "id": 197859,
#                 "latlon": "-37.656528,145.510315",
#                 "location": "266 Nicholson Street HEALESVILLE, YARRA RANGES SHIRE",
#                 "name": "Black Cat Boutique",
#                 "overlay_numbers": [
#                     "HO428"
#                 ],
#                 "p_precinct_name": "Healesville Commercial Precinct",
#                 "primary_image_caption": "266 Nicholson St, Healesville",
#                 "primary_image_id": 202764,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/202/764.jpg",
#                 "score": 0.22108552,
#                 "summary": "See Healesville Commercial Precinct page",
#                 "url": "http://vhd.heritage.vic.gov.au/places/197859",
#                 "vhr_number": null
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/47085"
#                     }
#                 },
#                 "heritage_authority_id": "8",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/8.gif",
#                 "heritage_authority_name": "Manningham City",
#                 "id": 47085,
#                 "latlon": "-37.787966,145.178283",
#                 "location": "1-29 and 12-26 Old Warrandyte Road and 1-8 Cat Jump Road DONVALE, MANNINGHAM CITY",
#                 "name": "Old Warrandyte Road Heritage Precinct",
#                 "overlay_numbers": [
#                     "HO122"
#                 ],
#                 "primary_image_caption": "47085 Trees - Old Warrandyte Road (looking north)",
#                 "primary_image_id": 39226,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/039/226.jpg",
#                 "score": 0.16598962,
#                 "summary": "The Old Warrandyte Road precinct, comprising the road reserve and private properties at 1-29 &amp; 12-26 Old Warrandyte Road and 1-6 Cat Jump Road, Donvale.\nHow is it Significant?\nThe Old&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/47085",
#                 "vhr_number": null
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/22495"
#                     }
#                 },
#                 "heritage_authority_id": "8",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/8.gif",
#                 "heritage_authority_name": "Manningham City",
#                 "id": 22495,
#                 "latlon": "-37.784758,145.181448",
#                 "location": "2-4 Cat Jump Road DONVALE, Manningham City",
#                 "name": "WORRALL",
#                 "overlay_numbers": [
#                     "HO31"
#                 ],
#                 "p_precinct_name": "Old Warrandyte Road Heritage Precinct",
#                 "primary_image_caption": "22495 Worrall - 4 Cat Jump Road, Donvalel",
#                 "primary_image_id": 18014,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/018/014.jpg",
#                 "score": 0.075077474,
#                 "summary": "Probably of State significance as one of the earliest modern houses in Victoria designed and built by the important domestic architect Percy H. Meldrum for himself and his family in&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/22495",
#                 "vhr_number": null
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/22510"
#                     }
#                 },
#                 "heritage_authority_id": "8",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/8.gif",
#                 "heritage_authority_name": "Manningham City",
#                 "id": 22510,
#                 "latlon": "-37.788850,145.175399",
#                 "location": "15 Old Warrandyte Road DONVALE, Manningham City",
#                 "name": "IAN H. GRABOWSKY HOUSE",
#                 "overlay_numbers": [
#                     "HO123"
#                 ],
#                 "p_precinct_name": "Old Warrandyte Road Heritage Precinct",
#                 "primary_image_caption": "22510 Ian H. Grabowsky House - 15 Old Warrandyte Road, Donvale (A)",
#                 "primary_image_id": 18018,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/018/018.jpg",
#                 "score": 0.045865674,
#                 "summary": "Of regional significance. A typical early modern house design of this period by important domestic architect Percy H. Meldrum and with 4 Cat Jump Road (214.19), 16 &amp; 21 Old Warrandyte&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/22510",
#                 "vhr_number": null
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/22512"
#                     }
#                 },
#                 "heritage_authority_id": "8",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/8.gif",
#                 "heritage_authority_name": "Manningham City",
#                 "id": 22512,
#                 "latlon": "-37.788225,145.176925",
#                 "location": "21 Old Warrandyte Road DONVALE, Manningham City",
#                 "name": "JOSEPH ALEXANDER HOUSE",
#                 "overlay_numbers": [
#                     "HO125"
#                 ],
#                 "p_precinct_name": "Old Warrandyte Road Heritage Precinct",
#                 "primary_image_caption": "22512 Alexander House - 21 Old Warrandyte Road, Donvale (1)",
#                 "primary_image_id": 28246,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/028/246.jpg",
#                 "score": 0.036692537,
#                 "summary": "Of local architectural significance as an early modern design by important domestic architect Percy H. Meldrum, c1941. It has been unfortunately much altered, most insensitively. One of a&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/22512",
#                 "vhr_number": null
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/22923"
#                     }
#                 },
#                 "heritage_authority_id": "8",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/8.gif",
#                 "heritage_authority_name": "Manningham City",
#                 "id": 22923,
#                 "latlon": "-37.758538,145.084846",
#                 "location": "7 Templestowe Road BULLEEN, Manningham City",
#                 "name": "Garden at Heide I",
#                 "overlay_numbers": [
#                     "HO160"
#                 ],
#                 "primary_image_caption": "Manningham Heritage Garden &amp; Significant Tree Study 2006",
#                 "primary_image_id": 16726,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/016/726.jpg",
#                 "score": 0.03210597,
#                 "summary": "The garden surrounding Heide I at 7 Templestowe Road, Bulleen is of State significance for its aesthetic and cultural value, being the home of art patrons John and Sunday Reed. The garden is&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/22923",
#                 "vhr_number": "H0687"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/118285"
#                     }
#                 },
#                 "heritage_authority_id": "5",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/5.gif",
#                 "heritage_authority_name": "Boroondara City",
#                 "id": 118285,
#                 "latlon": "-37.799660,145.024521",
#                 "location": "52 Fellows Street KEW, BOROONDARA CITY",
#                 "name": "52 Fellows Street",
#                 "overlay_numbers": [
#                     "HO563"
#                 ],
#                 "score": 0.027519403,
#                 "summary": "&nbsp;\n\n&nbsp;\n52 Fellows Street is a finely executed triple-fronted timber residence of the late nineteenth century, with highly decorated and worked timber detailing. The house has a hipped&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/118285",
#                 "vhr_number": null
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/153364"
#                     }
#                 },
#                 "heritage_authority_id": "30",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/30.gif",
#                 "heritage_authority_name": "Stonnington City",
#                 "id": 153364,
#                 "latlon": "-37.838940,145.005513",
#                 "location": "284 WILLIAMS ROAD,, TOORAK VIC 3142 - Property No 36142",
#                 "name": "PARK MANOR",
#                 "overlay_numbers": [
#                     "HO155"
#                 ],
#                 "p_precinct_name": "Williams Road Precinct",
#                 "primary_image_caption": "Park Manor",
#                 "primary_image_id": 150003,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/150/003.jpg",
#                 "score": 0.027519403,
#                 "summary": "This place was reviewed by Residential Flats in Stonnington Study Stage 2 (Context, 2011) and is recommended for detailed assessment in Stage 3. It is of potential significance:\n\nAs a good&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/153364",
#                 "vhr_number": null
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/68385"
#                     }
#                 },
#                 "heritage_authority_id": "58",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/58.gif",
#                 "heritage_authority_name": "National Trust",
#                 "id": 68385,
#                 "latlon": "-38.153515,144.365607",
#                 "location": "202 Myers Street, GEELONG VIC 3220 - Property No B3199",
#                 "name": "Old Geelong Gaol",
#                 "primary_image_caption": "B3199 Old Geelong Gaol",
#                 "primary_image_id": 70078,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/070/078.jpg",
#                 "score": 0.022932837,
#                 "summary": "Gaol buildings built between 1853 and 1865 on cruciform plan standard during the last century, of which few examples remain. They include the west wing (1853) with additional third storey&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/68385",
#                 "vhr_number": "H0961"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/65060"
#                     }
#                 },
#                 "heritage_authority_id": "58",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/58.gif",
#                 "heritage_authority_name": "National Trust",
#                 "id": 65060,
#                 "latlon": "-37.817005,145.062314",
#                 "location": "46 Parlington Street, CANTERBURY VIC 3126 - Property No B1515",
#                 "name": "Verulam",
#                 "primary_image_caption": "B1515 Verulam",
#                 "primary_image_id": 195105,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/195/105.jpg",
#                 "score": 0.019459154,
#                 "summary": "Verulam was constructed in 1888 for James Mackintosh, a pioneer sawmiller from Echuca. Mackintosh had purchased the site from William Elsdon, a leading figure in the Melbourne &amp;&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/65060",
#                 "vhr_number": "H0731"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/125841"
#                     }
#                 },
#                 "heritage_authority_id": "83",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/83.gif",
#                 "heritage_authority_name": "Vic. War Heritage Inventory",
#                 "id": 125841,
#                 "latlon": "-35.450770,143.627040",
#                 "location": "WILLAKOOL DRIVE LAKE BOGA, SWAN HILL RURAL CITY",
#                 "name": "Lake Boga Flying Boat Depot",
#                 "overlay_numbers": [
#                     "HO43"
#                 ],
#                 "primary_image_caption": "H2208 1-Lake Boga Catalina Feb 09 PM2",
#                 "primary_image_id": 96298,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/096/298.jpg",
#                 "score": 0.016215961,
#                 "summary": "The Lake Boga Flying Boat Museum is located on a foreshore site which was part of the World War II RAAF Flying Boat Repair Depot. It features an original communications bunker, slipways, a&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/125841",
#                 "vhr_number": "H2208"
#             },
#             {
#                 "_links": {
#                     "self": {
#                         "href": "https://api.heritagecouncil.vic.gov.au/v1/places/199409"
#                     }
#                 },
#                 "heritage_authority_id": "6",
#                 "heritage_authority_logo": "https://api.heritagecouncil.vic.gov.au/img/owner_icons/6.gif",
#                 "heritage_authority_name": "Greater Geelong City",
#                 "id": 199409,
#                 "latlon": "-38.146420,144.332794",
#                 "location": "23 Upper Skene Street NEWTOWN, GREATER GEELONG CITY",
#                 "name": "Dwelling",
#                 "overlay_numbers": [
#                     "HO2005"
#                 ],
#                 "p_precinct_name": "Upper Skene Street",
#                 "primary_image_caption": "23 Upper Skene Street, Newtown",
#                 "primary_image_id": 206525,
#                 "primary_image_url": "http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/206/525.jpg",
#                 "score": 0.016052986,
#                 "summary": "Contributory Significance- Newtown West Heritage Area\nHistory/Notes\nThe land at 23 Upper Skene Street was offered for sale as lot 4 of the McQueen Estate in 1928. It was sold to Bruce Mills&hellip;",
#                 "url": "http://vhd.heritage.vic.gov.au/places/199409",
#                 "vhr_number": null
#             }
#         ]
#     },
#     "_links": {
#         "first": {
#             "href": "https://api.heritagecouncil.vic.gov.au/v1/places?kw=cats"
#         },
#         "last": {
#             "href": "https://api.heritagecouncil.vic.gov.au/v1/places?kw=cats&page=1"
#         },
#         "self": {
#             "href": "https://api.heritagecouncil.vic.gov.au/v1/places?kw=cats&page=1"
#         }
#     },
#     "facets": {
#         "architectural_style": {
#             "id_30": {
#                 "count": 1,
#                 "id": "30",
#                 "name": "Interwar Period (c.1919-c.1940) Moderne"
#             },
#             "id_52": {
#                 "count": 1,
#                 "id": "52",
#                 "name": "Late Twentieth Century (c.1960-c.2000) International"
#             }
#         },
#         "heritage_act_category": {
#             "id_1": {
#                 "count": 5,
#                 "id": "1",
#                 "name": "Registered place"
#             },
#             "id_12": {
#                 "count": 1,
#                 "id": "12",
#                 "name": "Registered object integral to a registered place"
#             },
#             "id_2": {
#                 "count": 1,
#                 "id": "2",
#                 "name": "Registered object"
#             },
#             "id_3": {
#                 "count": 1,
#                 "id": "3",
#                 "name": "Registered archaeological place"
#             }
#         },
#         "heritage_authorities": {
#             "id_1086": {
#                 "count": 4,
#                 "id": "1086",
#                 "name": "Victorian Heritage Register"
#             },
#             "id_1087": {
#                 "count": 2,
#                 "id": "1087",
#                 "name": "Victorian Heritage Inventory"
#             },
#             "id_30": {
#                 "count": 1,
#                 "id": "30",
#                 "name": "Stonnington City"
#             },
#             "id_5": {
#                 "count": 1,
#                 "id": "5",
#                 "name": "Boroondara City"
#             },
#             "id_58": {
#                 "count": 2,
#                 "id": "58",
#                 "name": "National Trust"
#             },
#             "id_6": {
#                 "count": 1,
#                 "id": "6",
#                 "name": "Greater Geelong City"
#             },
#             "id_75": {
#                 "count": 1,
#                 "id": "75",
#                 "name": "Yarra Ranges Shire"
#             },
#             "id_8": {
#                 "count": 5,
#                 "id": "8",
#                 "name": "Manningham City"
#             },
#             "id_83": {
#                 "count": 1,
#                 "id": "83",
#                 "name": "Vic. War Heritage Inventory"
#             }
#         },
#         "municipality": {
#             "id_19": {
#                 "count": 1,
#                 "id": "19",
#                 "name": "EAST GIPPSLAND SHIRE"
#             },
#             "id_25": {
#                 "count": 1,
#                 "id": "25",
#                 "name": "GREATER BENDIGO CITY"
#             },
#             "id_27": {
#                 "count": 2,
#                 "id": "27",
#                 "name": "GREATER GEELONG CITY"
#             },
#             "id_40": {
#                 "count": 6,
#                 "id": "40",
#                 "name": "MANNINGHAM CITY"
#             },
#             "id_43": {
#                 "count": 1,
#                 "id": "43",
#                 "name": "MELBOURNE CITY"
#             },
#             "id_53": {
#                 "count": 1,
#                 "id": "53",
#                 "name": "MOUNT ALEXANDER SHIRE"
#             },
#             "id_63": {
#                 "count": 1,
#                 "id": "63",
#                 "name": "STONNINGTON CITY"
#             },
#             "id_66": {
#                 "count": 2,
#                 "id": "66",
#                 "name": "SWAN HILL RURAL CITY"
#             },
#             "id_78": {
#                 "count": 1,
#                 "id": "78",
#                 "name": "YARRA RANGES SHIRE"
#             },
#             "id_8": {
#                 "count": 2,
#                 "id": "8",
#                 "name": "BOROONDARA CITY"
#             }
#         },
#         "period": {
#             "id_2": {
#                 "count": 2,
#                 "id": "2",
#                 "name": "1850 - 1879"
#             },
#             "id_4": {
#                 "count": 1,
#                 "id": "4",
#                 "name": "1910 - 1939"
#             },
#             "id_5": {
#                 "count": 2,
#                 "id": "5",
#                 "name": "1940 - 1969"
#             }
#         },
#         "primary_category": {
#             "id_10": {
#                 "count": 1,
#                 "id": "10",
#                 "name": "Law Enforcement",
#                 "secondary_category": [
#                     {
#                         "count": 1,
#                         "id": "195",
#                         "name": "Gaol/Lock-up"
#                     }
#                 ]
#             },
#             "id_13": {
#                 "count": 2,
#                 "id": "13",
#                 "name": "Military",
#                 "secondary_category": [
#                     {
#                         "count": 2,
#                         "id": "260",
#                         "name": "Defence Base Airforce"
#                     },
#                     {
#                         "count": 2,
#                         "id": "270",
#                         "name": "Military aircraft"
#                     }
#                 ]
#             },
#             "id_14": {
#                 "count": 3,
#                 "id": "14",
#                 "name": "Mining and Mineral Processing",
#                 "secondary_category": [
#                     {
#                         "count": 2,
#                         "id": "699",
#                         "name": "Other - Mining &amp; Mineral Processing"
#                     },
#                     {
#                         "count": 1,
#                         "id": "283",
#                         "name": "Battery/Crusher"
#                     },
#                     {
#                         "count": 1,
#                         "id": "295",
#                         "name": "Mine - Open Cut"
#                     },
#                     {
#                         "count": 1,
#                         "id": "307",
#                         "name": "Powder Magazine"
#                     },
#                     {
#                         "count": 1,
#                         "id": "742",
#                         "name": "Mullock Heap"
#                     }
#                 ]
#             },
#             "id_15": {
#                 "count": 2,
#                 "id": "15",
#                 "name": "Monuments and Memorials",
#                 "secondary_category": [
#                     {
#                         "count": 2,
#                         "id": "325",
#                         "name": "War Memorial"
#                     },
#                     {
#                         "count": 2,
#                         "id": "343",
#                         "name": "Statue"
#                     }
#                 ]
#             },
#             "id_16": {
#                 "count": 4,
#                 "id": "16",
#                 "name": "Parks, Gardens and Trees",
#                 "secondary_category": [
#                     {
#                         "count": 7,
#                         "id": "472",
#                         "name": "House"
#                     },
#                     {
#                         "count": 2,
#                         "id": "336",
#                         "name": "Garden Residential"
#                     },
#                     {
#                         "count": 2,
#                         "id": "343",
#                         "name": "Statue"
#                     },
#                     {
#                         "count": 1,
#                         "id": "328",
#                         "name": "Conservatory"
#                     },
#                     {
#                         "count": 1,
#                         "id": "340",
#                         "name": "Planting exotic"
#                     },
#                     {
#                         "count": 1,
#                         "id": "341",
#                         "name": "Planting groups"
#                     },
#                     {
#                         "count": 1,
#                         "id": "946",
#                         "name": "Park or Garden Precinct"
#                     }
#                 ]
#             },
#             "id_25": {
#                 "count": 2,
#                 "id": "25",
#                 "name": "Recreation and Entertainment",
#                 "secondary_category": [
#                     {
#                         "count": 7,
#                         "id": "472",
#                         "name": "House"
#                     },
#                     {
#                         "count": 1,
#                         "id": "403",
#                         "name": "Art Gallery/ Museum"
#                     },
#                     {
#                         "count": 1,
#                         "id": "441",
#                         "name": "Zoo"
#                     }
#                 ]
#             },
#             "id_27": {
#                 "count": 9,
#                 "id": "27",
#                 "name": "Residential buildings (private)",
#                 "secondary_category": [
#                     {
#                         "count": 7,
#                         "id": "472",
#                         "name": "House"
#                     },
#                     {
#                         "count": 1,
#                         "id": "470",
#                         "name": "Flat"
#                     },
#                     {
#                         "count": 1,
#                         "id": "477",
#                         "name": "Mansion"
#                     },
#                     {
#                         "count": 1,
#                         "id": "478",
#                         "name": "Residential Contents (movable)"
#                     },
#                     {
#                         "count": 1,
#                         "id": "495",
#                         "name": "Shop"
#                     }
#                 ]
#             },
#             "id_36": {
#                 "count": 1,
#                 "id": "36",
#                 "name": "Landscape - Cultural",
#                 "secondary_category": [
#                     {
#                         "count": 1,
#                         "id": "626",
#                         "name": "Historic Landscape"
#                     }
#                 ]
#             },
#             "id_38": {
#                 "count": 1,
#                 "id": "38",
#                 "name": "Aboriginal",
#                 "secondary_category": [
#                     {
#                         "count": 1,
#                         "id": "631",
#                         "name": "Modified tree"
#                     }
#                 ]
#             },
#             "id_40": {
#                 "count": 1,
#                 "id": "40",
#                 "name": "Commercial",
#                 "secondary_category": [
#                     {
#                         "count": 7,
#                         "id": "472",
#                         "name": "House"
#                     },
#                     {
#                         "count": 1,
#                         "id": "495",
#                         "name": "Shop"
#                     }
#                 ]
#             },
#             "id_43": {
#                 "count": 1,
#                 "id": "43",
#                 "name": "Public Art",
#                 "secondary_category": [
#                     {
#                         "count": 2,
#                         "id": "343",
#                         "name": "Statue"
#                     }
#                 ]
#             }
#         },
#         "primary_theme": {
#             "id_9": {
#                 "count": 1,
#                 "id": "9",
#                 "name": "9. Shaping cultural and creative life",
#                 "secondary_theme": [
#                     {
#                         "count": 1,
#                         "id": "56",
#                         "name": "9.1 Participating in sport and recreation"
#                     },
#                     {
#                         "count": 1,
#                         "id": "60",
#                         "name": "9.5 Advancing knowledge"
#                     }
#                 ]
#             }
#         }
#     },
#     "page_count": 1,
#     "page_size": 25,
#     "spelling_suggestion": [],
#     "total_items": 18
# }

# %% [markdown]
# That's a lot of information that comes back in a search result. It's worth browsing through to inspire yourself about what
# might be possible with this kind of data.
#
# In the following code we pull out some key information from all the places returned in the search results.

# %%
myURL = "https://api.heritagecouncil.vic.gov.au/v1/places?kw=cats"
myLoadedURL = requests.get(myURL)
myJSONdata = json.loads(myLoadedURL.text)
# Instead of outputing all of the data we loop through each place in the JSON
for place in myJSONdata["_embedded"]["places"]:
    # Within each place we print out the name:
    print(place.get("name"))
    # A link to an image of the place:
    print(place.get("primary_image_url"))
    # And finally a link to the full record of the place on the website:
    print("https://vhd.heritagecouncil.vic.gov.au/places/" + str(place.get("id")))
# Out:
# LAKE BOGA FLYING BOAT MUSEUM
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/066/223.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/55888
# ROYAL MELBOURNE ZOOLOGICAL GARDENS
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/078/765.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/4781
# HEIDE II
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/077/600.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/180
# ROSALIND PARK
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/078/410.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/1774
# BLACK CAT BATTERY
# None
# https://vhd.heritagecouncil.vic.gov.au/places/11057
# CAPPERS REEF WORKINGS
# None
# https://vhd.heritagecouncil.vic.gov.au/places/7906
# Black Cat Boutique
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/202/764.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/197859
# Old Warrandyte Road Heritage Precinct
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/039/226.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/47085
# WORRALL
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/018/014.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/22495
# IAN H. GRABOWSKY HOUSE
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/018/018.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/22510
# JOSEPH ALEXANDER HOUSE
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/028/246.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/22512
# Garden at Heide I
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/016/726.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/22923
# 52 Fellows Street
# None
# https://vhd.heritagecouncil.vic.gov.au/places/118285
# PARK MANOR
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/150/003.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/153364
# Old Geelong Gaol
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/070/078.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/68385
# Verulam
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/195/105.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/65060
# Lake Boga Flying Boat Depot
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/096/298.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/125841
# Dwelling
# http://vhd.heritagecouncil.vic.gov.au/vhd-images/places/000/206/525.jpg
# https://vhd.heritagecouncil.vic.gov.au/places/199409

# %% [markdown]
# ----
#
# Created by [Mitchell Harrop](https://people.eng.unimelb.edu.au/mharrop/) for the [GLAM Workbench](https://glam-workbench.net/).
